# %% [markdown]
# <h1 align='center'>
# <br>
#     <img src="./assets/ibm_x_taiwan.png" alt="IBM Course" width="400">
# <br>
#     Applied Data Science Capstone
# </h1>
#
#
# <h2 align='center'>
# The Battle of Neighborhoods - A Look Around Universities in Taiwan
# </h2>
#
# <h5 align='center'>
#     Brian L. Chen, Feb., 2021
# </h5>
#
#
# ## 1. Introduction
#
# ### 1.1 Background
# Taiwan is known for its outstanding performance throughout this pandemic, and students from all over the world urge to know more about the unique island. Taiwan strictly performs its regulation and carries out a 14-day quarantine for people who are allowed to enter the island, including Taiwanese citizens.
#
# Besides the restrictions, Taiwan is also known for its high population density (ranked 17th worldwide in 2019 according to [statista](https://www.statista.com/statistics/264683/top-fifty-countries-with-the-highest-population-density/)), beautiful mountains, and convenience.
#
# As a student currently studying in Taiwan, providing an insightful analysis to the local universities in terms of convenience would be interesting for future students when it comes to choosing which university to go to. Though it may be somewhat absurd only choosing universities based on their convenience, it is still something worth noticing, especially for those who haven't actually been to a specific university before.
#
# Moreover, as a gym-goer and a sports fanatic, picking an university surrounded by sports facilities is always considerable.
#
# ### 1.2 Interest
#
# The project is then aiming (1) **to examine the neighborhood of each university in Taiwan, exploring how it is like to live around its neighborhood**, and (2) **to inspect the sports facilities around each university in Taiwan**.
#
# The aim is to help future students choose their universities in terms on what their neighborhoods have to offer and what they would like to experience. The second part of this project could also help students playing sports gain a better perspective on which school to go to based on their preferences.
#
#
# <div class='alert alert-block alert-warning' style='margin-top: 20px'>
# 🗒️ Notice<br>
# I am not here to get involved in any political issues. Taiwan is a beautiful place with beautiful people, and the project aims to provide insights regarding the universities on the island. Please do not add extra political perspective towards this project.
# </div>
#
# ![](https://dynaimage.cdn.cnn.com/cnn/q_auto,w_900,c_fill,g_auto,h_506,ar_16:9/http%3A%2F%2Fcdn.cnn.com%2Fcnnnext%2Fdam%2Fassets%2F180719131350-beautiful-taiwan-popumon-alishan.jpg)
#
# ## 2. Data Acquisition and Cleaning
#
# ### 2.1 Data Sources
# #### 2.1.1 List of Accredited Taiwan Universities
# The data of listed universities is from the Ministry of Education, which can be found [here](https://ulist.moe.gov.tw/Download/FileDownload). The data contains the following information:
#
# + School ID
# + Private/Public Status
# + System/Institution
# + University Name (in Chinese)
# + University Name (in English)
# + Principal of the university
# + County
# + School District
# + Postal Code
# + School Address (in Chinese)
# + Tel
# + School Website
#
# Since longitude and latitude for each school is not listed, **[HERE API](https://developer.here.com)** is used to fetch the data needed to be further processed using Foursquare. The final outcome is *stored locally* so that the API calls will not be provoked everytime when I restart the kernal.
#
# The final attributes include:
#
# + Serial Number
# + ID
# + Public/Private
# + System
# + Name
# + Eng. Name
# + Postal Code
# + Latitude
# + Longitude
# + Address
# + City
# + County
# + Neighborhood
# + County (zh)
#
# #### 2.1.2 Geojson Data of Taiwan
# The **geojson data** of Taiwan is obtained to plot the choropleth map. The data helps define the boundaries for each county in Taiwan. It is provided by **[g0v](https://github.com/g0v/twgeojson)**. Since the data hasn't been updated for nearly 6 years, some content from the dataset needs to be corrected.
#
# I'm fetching [this](https://raw.githubusercontent.com/g0v/twgeojson/master/json/twCounty2010.geo.json) particular geojson data. As an example of the correction, 桃園縣 (Taoyuan County) needs to be corrected to 桃園市 (Taoyuan City).
#
# #### 2.1.3 Information of Venues Around Universities
# [Foursquare API](https://developer.foursquare.com) is used to obtain the final list of venues to be further examined. Also note that Foursquare API uses special "category id" for each category. Since I am collecting a series of fitness/gym sites, scraping (instead of connecting through [its API](https://developer.foursquare.com/docs/api-reference/venues/categories/) the [venue category page](https://developer.foursquare.com/docs/build-with-foursquare/categories/) works better for me. I am collecting data with the following information:
#
# + University (zh)
# + University (eng)
# + University Latitude
# + University Longitude
# + Venue
# + Venue Latitude
# + Venue Longitude
# + Venue Category
#
# #### 2.1.4 Results
# Last but not least, there would be a total of **five** datasets to make analysis from:
#
# 1. Venues within 1,500m for each university on the list - to examine the convenience of each university
# 2. Sports venues within 1,000m and 2,000m
# 3. Gym venues only within 1,0000m and 2,000m

# %% [markdown]
# ### 2.2 Data Processing

# %%
# Import libraries

import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests
import json
import geocoder
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from tqdm.notebook import tqdm
from tqdm.contrib import tzip
import math

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt # plotting library
# %matplotlib inline 

# import k-means from clustering stage
from sklearn.cluster import KMeans


import folium # map rendering library

# scraping libraries
from bs4 import BeautifulSoup

plt.style.use('ggplot') # refined style

# %% [markdown]
# Since the csv file is downloaded directly from the Ministry of Education, the contents are mainly in Chinese.

# %%
rdf.head()
# Out:
#    序號  學校代碼 公私立    體制      學校名稱                             學校英文名稱  職稱   姓名  \
# 0   1  0001  公立  一般大學    國立政治大學     National Chengchi Universerity  校長  郭明政
# 1   2  0002  公立  一般大學    國立清華大學      National Tsing Hua University  校長  賀陳弘
# 2   3  0003  公立  一般大學    國立臺灣大學         NATIONAL TAIWAN UNIVERSITY  校長  管中閔
# 3   4  0004  公立  一般大學  國立臺灣師範大學  National Taiwan Normal University  校長  吳正己
# 4   5  0005  公立  一般大學    國立成功大學     National Cheng Kung University  校長  蘇慧貞
#
#    縣市別 第三級行政區   郵遞區號              學校地址          學校總機          學校傳真  \
# 0  臺北市    文山區  11605    臺北市文山區指南路2段64號  02-2939-3091  02-2937-9611
# 1  新竹市    新竹市  30013      新竹市光復路2段101號   03-571-5131   03-572-4038
# 2  臺北市    大安區  10617    臺北市大安區羅斯福路4段1號  02-3366-3366  02-2362-7651
# 3  臺北市    大安區  10610  臺北市大安區和平東路1段162號  02-7749-1111             無
# 4  臺南市    東　區  70101        臺南市東區大學路1號   06-275-7575   06-276-6462
#
#                        網址
# 0  http://www.nccu.edu.tw
# 1  http://www.nthu.edu.tw
# 2   http://www.ntu.edu.tw
# 3  http://www.ntnu.edu.tw
# 4  http://www.ncku.edu.tw

# %% [markdown]
# For this, we will select specific columns and use some of them in our [HERE API](https://developer.here.com) calls.

# %%
pdf = rdf.rename(columns={'序號': 'Serial Number', '學校代碼': 'ID', '公私立': 'Public/Private', '體制': 'System', '學校名稱': 'Name', '學校英文名稱': 'Eng. Name', '郵遞區號':'Postal Code', '學校總機': 'Tel','學校傳真': 'Fax','網址': 'URL'})
pdf['Public/Private'].replace(to_replace=['公立','私立'], value=['Public', 'Private'],inplace=True)
selected = ['Serial Number',
 'ID',
 'Public/Private',
 'System',
 'Name',
 'Eng. Name',
 'Postal Code',
 '縣市別',
 '第三級行政區',
 '學校地址']

pdf = pdf[selected]
pdf.head()
# Out:
#    Serial Number    ID Public/Private System      Name  \
# 0              1  0001         Public   一般大學    國立政治大學
# 1              2  0002         Public   一般大學    國立清華大學
# 2              3  0003         Public   一般大學    國立臺灣大學
# 3              4  0004         Public   一般大學  國立臺灣師範大學
# 4              5  0005         Public   一般大學    國立成功大學
#
#                            Eng. Name  Postal Code  縣市別 第三級行政區  \
# 0     National Chengchi Universerity        11605  臺北市    文山區
# 1      National Tsing Hua University        30013  新竹市    新竹市
# 2         NATIONAL TAIWAN UNIVERSITY        10617  臺北市    大安區
# 3  National Taiwan Normal University        10610  臺北市    大安區
# 4     National Cheng Kung University        70101  臺南市    東　區
#
#                學校地址
# 0    臺北市文山區指南路2段64號
# 1      新竹市光復路2段101號
# 2    臺北市大安區羅斯福路4段1號
# 3  臺北市大安區和平東路1段162號
# 4        臺南市東區大學路1號

# %%
# define the dataframe columns
column_names = ['Serial Number',
 'ID',
 'Public/Private',
 'System',
 'Name',
 'Eng. Name',
 'Postal Code', 
 'Latitude', 
 'Longitude', 
 'Address',
 'City',
 'County',
 'Neighborhood'] 

# instantiate the dataframe
updf = pd.DataFrame(columns=column_names)
updf
# Out:
# Empty DataFrame
# Columns: [Serial Number, ID, Public/Private, System, Name, Eng. Name, Postal Code, Latitude, Longitude, Address, City, County, Neighborhood]
# Index: []

# %%
# Credentials HERE API
APP_ID = ''
APP_CODE = ''

# %%
for data in tqdm(pdf.to_dict(orient='records')):
    """
    ['Serial Number',
     'ID',
     'Public/Private',
     'System',
     'Name',
     'Eng. Name',
     'Postal Code',
     '縣市別',
     '第三級行政區',
     '學校地址']
    """
    Serial_Number = data['Serial Number']
    ID = data['ID']
    Public_Private = data['Public/Private']
    System = data['System']
    Name = data['Name']
    Eng_Name = data['Eng. Name']
    Postal_Code = data['Postal Code']
    address_zh = data['學校地址']
    county_zh = data['縣市別']
    
    g = geocoder.here(address_zh,
                       app_id=APP_ID,
                       app_code=APP_CODE)
    result = g.json
    
    Latitude = result['lat']
    Longitude = result['lng']
    Address = result['address']
    City = result['city']
    County = result['county']
    if 'neighborhood' in result:
        Neighborhood = result['neighborhood']
    else:
        Neighborhood = np.nan
    updf = updf.append({
        'Serial Number': Serial_Number,
        'ID': ID,
        'Public/Private': Public_Private,
        'System':System,
        'Name': Name,
        'Eng. Name': Eng_Name,
        'Postal Code': Postal_Code,
        'Latitude':Latitude,
        'Longitude': Longitude,
        'Address': Address,
        'City': City,
        'County': County,
        'Neighborhood': Neighborhood,
        'County (zh)': county_zh}, ignore_index=True
    )

updf.head()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=160.0), HTML(value='')))
#   Serial Number    ID Public/Private System      Name  \
# 0             1  0001         Public   一般大學    國立政治大學
# 1             2  0002         Public   一般大學    國立清華大學
# 2             3  0003         Public   一般大學    國立臺灣大學
# 3             4  0004         Public   一般大學  國立臺灣師範大學
# 4             5  0005         Public   一般大學    國立成功大學
#
#                            Eng. Name Postal Code  Latitude  Longitude  \
# 0     National Chengchi Universerity       11605  24.98741  121.57651
# 1      National Tsing Hua University       30013  24.79635  120.99686
# 2         NATIONAL TAIWAN UNIVERSITY       10617  25.01697  121.53369
# 3  National Taiwan Normal University       10610  25.02643  121.52756
# 4     National Cheng Kung University       70101  22.99632  120.21953
#
#                                              Address          City  \
# 0  No. 64, Sec 2, Zhi Nan Rd., Wenshan District, ...   Taipei City
# 1  No. 101, Sec 2, Guang Fu Rd., East District, H...  Hsinchu City
# 2  No. 1, Sec 4, Luo Si Fu Rd., Daan District, Ta...   Taipei City
# 3  No. 162, Sec 1, He Ping E. Rd., Daan District,...   Taipei City
# 4  No. 1, Da Syue Rd., East District, Tainan City...   Tainan City
#
#          County      Neighborhood County (zh)
# 0   Taipei City  Wenshan District         臺北市
# 1  Hsinchu City     East District         新竹市
# 2   Taipei City     Daan District         臺北市
# 3   Taipei City     Daan District         臺北市
# 4   Tainan City     East District         臺南市

# %%
updf.shape
# Out:
# (160, 14)

# %%
updf.to_csv('assets/data/p_ulist_2021-02-20.csv', index=False)

# %% [markdown]
# Now the data is ready to be sent to Foursquare API and make further exploration.

# %% [markdown]
# #### 2.2.1 Fetching Data with Foursquare API

# %%
df = pd.read_csv('assets/data/p_ulist_2021-02-20.csv')
udf = df.copy()
udf['Neighborhood'] = udf['Neighborhood'].fillna(udf['City'])
# check if we still have something that is null
udf.isnull().sum()
# Out:
# Serial Number     0
# ID                0
# Public/Private    0
# System            0
# Name              0
# Eng. Name         0
# Postal Code       0
# Latitude          0
# Longitude         0
# Address           0
# City              0
# County            0
# Neighborhood      0
# County (zh)       0
# dtype: int64

# %%
# Foursquare API Credentials
CODE = ''
url_to_access_token = ''
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = ''
LIMIT = 100 # A default Foursquare API limit value

# %%
def getNearbyVenues(namess, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    full_list = [] # for future reference, can be handful when examining different radius (don't haeve to rerun the quries again)
    (names, eng_names) = namess
    for name, eng_name, lat, lng in tzip(names, eng_names, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        full_list.append(results)
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, eng_name,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['University (zh)', 'University (eng)', 
                  'University Latitude', 
                  'University Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return nearby_venues, full_list

# %%
uni_venues = pd.DataFrame()
uni_venues, full_list_raw = getNearbyVenues((np.asarray(udf['Name']), np.asarray(udf['Eng. Name'])), np.asarray(udf.Latitude), np.asarray(udf.Longitude), radius=1500)
print(uni_venues.shape)
uni_venues.head()
len(uni_venues['University (zh)'].unique())
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=160.0), HTML(value='')))
# (4119, 8)
# 159

# %% [markdown]
# Here, we export the received DataFrame as a csv file for further usage.

# %%
uni_venues.to_csv('assets/data/uni_venues_1500_2021-02-20.csv', index=False)

# %%
print(uni_venues.shape)
uni_venues.groupby('University (zh)').count()
# Out:
# (4119, 8)
#                        University (eng)  University Latitude  \
# University (zh)
# 一貫道崇德學院                               4                    4
# 世新大學                                 93                   93
# 中信金融管理學院                              1                    1
# 中原大學                                 14                   14
# 中國文化大學                               36                   36
# 中國科技大學                               27                   27
# 中國醫藥大學                               45                   45
# 中山醫學大學                                9                    9
# 中州學校財團法人中州科技大學                        2                    2
# 中臺科技大學                               17                   17
# 中華大學學校財團法人中華大學                        7                    7
# 中華學校財團法人中華科技大學                       15                   15
# 中華醫事科技大學                              9                    9
# 亞東技術學院                               23                   23
# 亞洲大學                                  8                    8
# 仁德醫護管理專科學校                            7                    7
# 佛光大學                                  2                    2
# 修平學校財團法人修平科技大學                        3                    3
# 健行學校財團法人健行科技大學                       17                   17
# 僑光科技大學                               30                   30
# 元智大學                                 13                   13
# 光宇學校財團法人元培醫事科技大學                      6                    6
# 南亞科技學校財團法人南亞技術學院                      7                    7
# 南臺學校財團法人南臺科技大學                       11                   11
# 南華大學                                  1                    1
# 南開科技大學                                4                    4
# 台北海洋學校財團法人台北海洋科技大學                   10                   10
# 台南家專學校財團法人台南應用科技大學                   11                   11
# 台灣基督長老教會南神神學院                        84                   84
# 台灣首府學校財團法人台灣首府大學                      3                    3
# 台神學校財團法人台灣神學研究學院                     57                   57
# 吳鳳科技大學                                5                    5
# 和春技術學院                                1                    1
# 嘉藥學校財團法人嘉南藥理大學                        7                    7
# 國立中央大學                                6                    6
# 國立中山大學                               41                   41
# 國立中正大學                                4                    4
# 國立中興大學                               22                   22
# 國立交通大學                               42                   42
# 國立勤益科技大學                              6                    6
# 國立嘉義大學                                5                    5
# 國立宜蘭大學                               28                   28
# 國立屏東大學                               13                   13
# 國立屏東科技大學                              6                    6
# 國立彰化師範大學                              4                    4
# 國立成功大學                               63                   63
# 國立政治大學                               64                   64
# 國立暨南國際大學                              6                    6
# 國立東華大學                                5                    5
# 國立清華大學                               40                   40
# 國立澎湖科技大學                              6                    6
# 國立空中大學                               27                   27
# 國立聯合大學                                1                    1
# 國立臺中教育大學                            100                  100
# 國立臺中科技大學                             76                   76
# 國立臺北商業大學                            100                  100
# 國立臺北大學                               31                   31
# 國立臺北教育大學                            100                  100
# 國立臺北科技大學                            100                  100
# 國立臺北藝術大學                             47                   47
# 國立臺北護理健康大學                          100                  100
# 國立臺南大學                              100                  100
# 國立臺南藝術大學                              1                    1
# 國立臺南護理專科學校                          100                  100
# 國立臺東專科學校                              6                    6
# 國立臺灣大學                              100                  100
# 國立臺灣師範大學                            100                  100
# 國立臺灣戲曲學院                             91                   91
# 國立臺灣海洋大學                              6                    6
# 國立臺灣科技大學                            100                  100
# 國立臺灣藝術大學                             36                   36
# 國立臺灣體育運動大學                           77                   77
# 國立虎尾科技大學                             11                   11
# 國立金門大學                                4                    4
# 國立陽明大學                               57                   57
# 國立雲林科技大學                              7                    7
# 國立體育大學                                4                    4
# 國立高雄大學                                4                    4
# 國立高雄師範大學                             48                   48
# 國立高雄科技大學                             13                   13
# 國立高雄餐旅大學                              6                    6
# 城市學校財團法人臺北城市科技大學                     42                   42
# 大仁科技大學                                1                    1
# 大同大學                                100                  100
# 大同技術學院                               12                   12
# 大漢技術學院                                5                    5
# 大華學校財團法人敏實科技大學                        5                    5
# 大葉大學                                  2                    2
# 學校財團法人中華浸信會基督教台灣浸會神學院               100                  100
# 宏國學校財團法人宏國德霖科技大學                     12                   12
# 實踐大學                                 60                   60
# 崇仁醫護管理專科學校                            2                    2
# 崇右學校財團法人崇右影藝科技大學                     35                   35
# 崑山科技大學                                5                    5
# 嶺東科技大學                                4                    4
# 康寧學校財團法人康寧大學                         46                   46
# 廣亞學校財團法人育達科技大學                        1                    1
# 建國科技大學                               12                   12
# 弘光科技大學                                4                    4
# 德明財經科技大學                            100                  100
# 慈惠醫護管理專科學校                            2                    2
# 慈濟學校財團法人慈濟大學                         17                   17
# 慈濟學校財團法人慈濟科技大學                        9                    9
# 敏惠醫護管理專科學校                            3                    3
# 文藻學校財團法人文藻外語大學                       31                   31
# 新生醫護管理專科學校                            5                    5
# 明志科技大學                               14                   14
# 明新學校財團法人明新科技大學                        5                    5
# 明道學校財團法人明道大學                          2                    2
# 景文科技大學                                9                    9
# 朝陽科技大學                                5                    5
# 東南科技大學                               16                   16
# 東吳大學                                 53                   53
# 東方學校財團法人東方設計大學                        4                    4
# 東海大學                                 19                   19
# 樹人醫護管理專科學校                            4                    4
# 樹德科技大學                                4                    4
# 正修學校財團法人正修科技大學                       10                   10
# 法鼓學校財團法人法鼓文理學院                        6                    6
# 淡江大學學校財團法人淡江大學                       67                   67
# 玄奘大學                                  5                    5
# 環球學校財團法人環球科技大學                        3                    3
# 真理大學                                 62                   62
# 稻江科技暨管理學院                            12                   12
# 經國管理暨健康學院                             4                    4
# 美和學校財團法人美和科技大學                        6                    6
# 義守大學                                 11                   11
# 耕莘健康管理專科學校                           78                   78
# 聖母醫護管理專科學校                            4                    4
# 聖約翰科技大學                               4                    4
# 育英醫護管理專科學校                           10                   10
# 致理學校財團法人致理科技大學                       64                   64
# 臺北基督學院                               26                   26
# 臺北市立大學                              100                  100
# 臺北醫學大學                              100                  100
# 臺灣觀光學院                                8                    8
# 華夏學校財團法人華夏科技大學                       13                   13
# 華梵大學                                  1                    1
# 萬能學校財團法人萬能科技大學                       16                   16
# 蘭陽技術學院                               11                   11
# 財團法人一貫道天皇基金會一貫道天皇學院                   2                    2
# 輔仁大學                                 23                   23
# 輔英科技大學                                7                    7
# 逢甲大學                                 39                   39
# 遠東科技大學                                4                    4
# 醒吾學校財團法人醒吾科技大學                       14                   14
# 銘傳大學                                 50                   50
# 長庚大學                                  4                    4
# 長庚學校財團法人長庚科技大學                        4                    4
# 長榮大學                                  6                    6
# 開南大學                                  5                    5
# 靜宜大學                                  5                    5
# 馬偕學校財團法人馬偕醫學院                         8                    8
# 馬偕學校財團法人馬偕醫護管理專科學校                    8                    8
# 高苑科技大學                                5                    5
# 高雄市立空中大學                             15                   15
# 高雄醫學大學                               35                   35
# 黎明技術學院                                6                    6
# 龍華科技大學                                5                    5
#
#                        University Longitude  Venue  Venue Latitude  \
# University (zh)
# 一貫道崇德學院                                   4      4               4
# 世新大學                                     93     93              93
# 中信金融管理學院                                  1      1               1
# 中原大學                                     14     14              14
# 中國文化大學                                   36     36              36
# 中國科技大學                                   27     27              27
# 中國醫藥大學                                   45     45              45
# 中山醫學大學                                    9      9               9
# 中州學校財團法人中州科技大學                            2      2               2
# 中臺科技大學                                   17     17              17
# 中華大學學校財團法人中華大學                            7      7               7
# 中華學校財團法人中華科技大學                           15     15              15
# 中華醫事科技大學                                  9      9               9
# 亞東技術學院                                   23     23              23
# 亞洲大學                                      8      8               8
# 仁德醫護管理專科學校                                7      7               7
# 佛光大學                                      2      2               2
# 修平學校財團法人修平科技大學                            3      3               3
# 健行學校財團法人健行科技大學                           17     17              17
# 僑光科技大學                                   30     30              30
# 元智大學                                     13     13              13
# 光宇學校財團法人元培醫事科技大學                          6      6               6
# 南亞科技學校財團法人南亞技術學院                          7      7               7
# 南臺學校財團法人南臺科技大學                           11     11              11
# 南華大學                                      1      1               1
# 南開科技大學                                    4      4               4
# 台北海洋學校財團法人台北海洋科技大學                       10     10              10
# 台南家專學校財團法人台南應用科技大學                       11     11              11
# 台灣基督長老教會南神神學院                            84     84              84
# 台灣首府學校財團法人台灣首府大學                          3      3               3
# 台神學校財團法人台灣神學研究學院                         57     57              57
# 吳鳳科技大學                                    5      5               5
# 和春技術學院                                    1      1               1
# 嘉藥學校財團法人嘉南藥理大學                            7      7               7
# 國立中央大學                                    6      6               6
# 國立中山大學                                   41     41              41
# 國立中正大學                                    4      4               4
# 國立中興大學                                   22     22              22
# 國立交通大學                                   42     42              42
# 國立勤益科技大學                                  6      6               6
# 國立嘉義大學                                    5      5               5
# 國立宜蘭大學                                   28     28              28
# 國立屏東大學                                   13     13              13
# 國立屏東科技大學                                  6      6               6
# 國立彰化師範大學                                  4      4               4
# 國立成功大學                                   63     63              63
# 國立政治大學                                   64     64              64
# 國立暨南國際大學                                  6      6               6
# 國立東華大學                                    5      5               5
# 國立清華大學                                   40     40              40
# 國立澎湖科技大學                                  6      6               6
# 國立空中大學                                   27     27              27
# 國立聯合大學                                    1      1               1
# 國立臺中教育大學                                100    100             100
# 國立臺中科技大學                                 76     76              76
# 國立臺北商業大學                                100    100             100
# 國立臺北大學                                   31     31              31
# 國立臺北教育大學                                100    100             100
# 國立臺北科技大學                                100    100             100
# 國立臺北藝術大學                                 47     47              47
# 國立臺北護理健康大學                              100    100             100
# 國立臺南大學                                  100    100             100
# 國立臺南藝術大學                                  1      1               1
# 國立臺南護理專科學校                              100    100             100
# 國立臺東專科學校                                  6      6               6
# 國立臺灣大學                                  100    100             100
# 國立臺灣師範大學                                100    100             100
# 國立臺灣戲曲學院                                 91     91              91
# 國立臺灣海洋大學                                  6      6               6
# 國立臺灣科技大學                                100    100             100
# 國立臺灣藝術大學                                 36     36              36
# 國立臺灣體育運動大學                               77     77              77
# 國立虎尾科技大學                                 11     11              11
# 國立金門大學                                    4      4               4
# 國立陽明大學                                   57     57              57
# 國立雲林科技大學                                  7      7               7
# 國立體育大學                                    4      4               4
# 國立高雄大學                                    4      4               4
# 國立高雄師範大學                                 48     48              48
# 國立高雄科技大學                                 13     13              13
# 國立高雄餐旅大學                                  6      6               6
# 城市學校財團法人臺北城市科技大學                         42     42              42
# 大仁科技大學                                    1      1               1
# 大同大學                                    100    100             100
# 大同技術學院                                   12     12              12
# 大漢技術學院                                    5      5               5
# 大華學校財團法人敏實科技大學                            5      5               5
# 大葉大學                                      2      2               2
# 學校財團法人中華浸信會基督教台灣浸會神學院                   100    100             100
# 宏國學校財團法人宏國德霖科技大學                         12     12              12
# 實踐大學                                     60     60              60
# 崇仁醫護管理專科學校                                2      2               2
# 崇右學校財團法人崇右影藝科技大學                         35     35              35
# 崑山科技大學                                    5      5               5
# 嶺東科技大學                                    4      4               4
# 康寧學校財團法人康寧大學                             46     46              46
# 廣亞學校財團法人育達科技大學                            1      1               1
# 建國科技大學                                   12     12              12
# 弘光科技大學                                    4      4               4
# 德明財經科技大學                                100    100             100
# 慈惠醫護管理專科學校                                2      2               2
# 慈濟學校財團法人慈濟大學                             17     17              17
# 慈濟學校財團法人慈濟科技大學                            9      9               9
# 敏惠醫護管理專科學校                                3      3               3
# 文藻學校財團法人文藻外語大學                           31     31              31
# 新生醫護管理專科學校                                5      5               5
# 明志科技大學                                   14     14              14
# 明新學校財團法人明新科技大學                            5      5               5
# 明道學校財團法人明道大學                              2      2               2
# 景文科技大學                                    9      9               9
# 朝陽科技大學                                    5      5               5
# 東南科技大學                                   16     16              16
# 東吳大學                                     53     53              53
# 東方學校財團法人東方設計大學                            4      4               4
# 東海大學                                     19     19              19
# 樹人醫護管理專科學校                                4      4               4
# 樹德科技大學                                    4      4               4
# 正修學校財團法人正修科技大學                           10     10              10
# 法鼓學校財團法人法鼓文理學院                            6      6               6
# 淡江大學學校財團法人淡江大學                           67     67              67
# 玄奘大學                                      5      5               5
# 環球學校財團法人環球科技大學                            3      3               3
# 真理大學                                     62     62              62
# 稻江科技暨管理學院                                12     12              12
# 經國管理暨健康學院                                 4      4               4
# 美和學校財團法人美和科技大學                            6      6               6
# 義守大學                                     11     11              11
# 耕莘健康管理專科學校                               78     78              78
# 聖母醫護管理專科學校                                4      4               4
# 聖約翰科技大學                                   4      4               4
# 育英醫護管理專科學校                               10     10              10
# 致理學校財團法人致理科技大學                           64     64              64
# 臺北基督學院                                   26     26              26
# 臺北市立大學                                  100    100             100
# 臺北醫學大學                                  100    100             100
# 臺灣觀光學院                                    8      8               8
# 華夏學校財團法人華夏科技大學                           13     13              13
# 華梵大學                                      1      1               1
# 萬能學校財團法人萬能科技大學                           16     16              16
# 蘭陽技術學院                                   11     11              11
# 財團法人一貫道天皇基金會一貫道天皇學院                       2      2               2
# 輔仁大學                                     23     23              23
# 輔英科技大學                                    7      7               7
# 逢甲大學                                     39     39              39
# 遠東科技大學                                    4      4               4
# 醒吾學校財團法人醒吾科技大學                           14     14              14
# 銘傳大學                                     50     50              50
# 長庚大學                                      4      4               4
# 長庚學校財團法人長庚科技大學                            4      4               4
# 長榮大學                                      6      6               6
# 開南大學                                      5      5               5
# 靜宜大學                                      5      5               5
# 馬偕學校財團法人馬偕醫學院                             8      8               8
# 馬偕學校財團法人馬偕醫護管理專科學校                        8      8               8
# 高苑科技大學                                    5      5               5
# 高雄市立空中大學                                 15     15              15
# 高雄醫學大學                                   35     35              35
# 黎明技術學院                                    6      6               6
# 龍華科技大學                                    5      5               5
#
#                        Venue Longitude  Venue Category
# University (zh)
# 一貫道崇德學院                              4               4
# 世新大學                                93              93
# 中信金融管理學院                             1               1
# 中原大學                                14              14
# 中國文化大學                              36              36
# 中國科技大學                              27              27
# 中國醫藥大學                              45              45
# 中山醫學大學                               9               9
# 中州學校財團法人中州科技大學                       2               2
# 中臺科技大學                              17              17
# 中華大學學校財團法人中華大學                       7               7
# 中華學校財團法人中華科技大學                      15              15
# 中華醫事科技大學                             9               9
# 亞東技術學院                              23              23
# 亞洲大學                                 8               8
# 仁德醫護管理專科學校                           7               7
# 佛光大學                                 2               2
# 修平學校財團法人修平科技大學                       3               3
# 健行學校財團法人健行科技大學                      17              17
# 僑光科技大學                              30              30
# 元智大學                                13              13
# 光宇學校財團法人元培醫事科技大學                     6               6
# 南亞科技學校財團法人南亞技術學院                     7               7
# 南臺學校財團法人南臺科技大學                      11              11
# 南華大學                                 1               1
# 南開科技大學                               4               4
# 台北海洋學校財團法人台北海洋科技大學                  10              10
# 台南家專學校財團法人台南應用科技大學                  11              11
# 台灣基督長老教會南神神學院                       84              84
# 台灣首府學校財團法人台灣首府大學                     3               3
# 台神學校財團法人台灣神學研究學院                    57              57
# 吳鳳科技大學                               5               5
# 和春技術學院                               1               1
# 嘉藥學校財團法人嘉南藥理大學                       7               7
# 國立中央大學                               6               6
# 國立中山大學                              41              41
# 國立中正大學                               4               4
# 國立中興大學                              22              22
# 國立交通大學                              42              42
# 國立勤益科技大學                             6               6
# 國立嘉義大學                               5               5
# 國立宜蘭大學                              28              28
# 國立屏東大學                              13              13
# 國立屏東科技大學                             6               6
# 國立彰化師範大學                             4               4
# 國立成功大學                              63              63
# 國立政治大學                              64              64
# 國立暨南國際大學                             6               6
# 國立東華大學                               5               5
# 國立清華大學                              40              40
# 國立澎湖科技大學                             6               6
# 國立空中大學                              27              27
# 國立聯合大學                               1               1
# 國立臺中教育大學                           100             100
# 國立臺中科技大學                            76              76
# 國立臺北商業大學                           100             100
# 國立臺北大學                              31              31
# 國立臺北教育大學                           100             100
# 國立臺北科技大學                           100             100
# 國立臺北藝術大學                            47              47
# 國立臺北護理健康大學                         100             100
# 國立臺南大學                             100             100
# 國立臺南藝術大學                             1               1
# 國立臺南護理專科學校                         100             100
# 國立臺東專科學校                             6               6
# 國立臺灣大學                             100             100
# 國立臺灣師範大學                           100             100
# 國立臺灣戲曲學院                            91              91
# 國立臺灣海洋大學                             6               6
# 國立臺灣科技大學                           100             100
# 國立臺灣藝術大學                            36              36
# 國立臺灣體育運動大學                          77              77
# 國立虎尾科技大學                            11              11
# 國立金門大學                               4               4
# 國立陽明大學                              57              57
# 國立雲林科技大學                             7               7
# 國立體育大學                               4               4
# 國立高雄大學                               4               4
# 國立高雄師範大學                            48              48
# 國立高雄科技大學                            13              13
# 國立高雄餐旅大學                             6               6
# 城市學校財團法人臺北城市科技大學                    42              42
# 大仁科技大學                               1               1
# 大同大學                               100             100
# 大同技術學院                              12              12
# 大漢技術學院                               5               5
# 大華學校財團法人敏實科技大學                       5               5
# 大葉大學                                 2               2
# 學校財團法人中華浸信會基督教台灣浸會神學院              100             100
# 宏國學校財團法人宏國德霖科技大學                    12              12
# 實踐大學                                60              60
# 崇仁醫護管理專科學校                           2               2
# 崇右學校財團法人崇右影藝科技大學                    35              35
# 崑山科技大學                               5               5
# 嶺東科技大學                               4               4
# 康寧學校財團法人康寧大學                        46              46
# 廣亞學校財團法人育達科技大學                       1               1
# 建國科技大學                              12              12
# 弘光科技大學                               4               4
# 德明財經科技大學                           100             100
# 慈惠醫護管理專科學校                           2               2
# 慈濟學校財團法人慈濟大學                        17              17
# 慈濟學校財團法人慈濟科技大學                       9               9
# 敏惠醫護管理專科學校                           3               3
# 文藻學校財團法人文藻外語大學                      31              31
# 新生醫護管理專科學校                           5               5
# 明志科技大學                              14              14
# 明新學校財團法人明新科技大學                       5               5
# 明道學校財團法人明道大學                         2               2
# 景文科技大學                               9               9
# 朝陽科技大學                               5               5
# 東南科技大學                              16              16
# 東吳大學                                53              53
# 東方學校財團法人東方設計大學                       4               4
# 東海大學                                19              19
# 樹人醫護管理專科學校                           4               4
# 樹德科技大學                               4               4
# 正修學校財團法人正修科技大學                      10              10
# 法鼓學校財團法人法鼓文理學院                       6               6
# 淡江大學學校財團法人淡江大學                      67              67
# 玄奘大學                                 5               5
# 環球學校財團法人環球科技大學                       3               3
# 真理大學                                62              62
# 稻江科技暨管理學院                           12              12
# 經國管理暨健康學院                            4               4
# 美和學校財團法人美和科技大學                       6               6
# 義守大學                                11              11
# 耕莘健康管理專科學校                          78              78
# 聖母醫護管理專科學校                           4               4
# 聖約翰科技大學                              4               4
# 育英醫護管理專科學校                          10              10
# 致理學校財團法人致理科技大學                      64              64
# 臺北基督學院                              26              26
# 臺北市立大學                             100             100
# 臺北醫學大學                             100             100
# 臺灣觀光學院                               8               8
# 華夏學校財團法人華夏科技大學                      13              13
# 華梵大學                                 1               1
# 萬能學校財團法人萬能科技大學                      16              16
# 蘭陽技術學院                              11              11
# 財團法人一貫道天皇基金會一貫道天皇學院                  2               2
# 輔仁大學                                23              23
# 輔英科技大學                               7               7
# 逢甲大學                                39              39
# 遠東科技大學                               4               4
# 醒吾學校財團法人醒吾科技大學                      14              14
# 銘傳大學                                50              50
# 長庚大學                                 4               4
# 長庚學校財團法人長庚科技大學                       4               4
# 長榮大學                                 6               6
# 開南大學                                 5               5
# 靜宜大學                                 5               5
# 馬偕學校財團法人馬偕醫學院                        8               8
# 馬偕學校財團法人馬偕醫護管理專科學校                   8               8
# 高苑科技大學                               5               5
# 高雄市立空中大學                            15              15
# 高雄醫學大學                              35              35
# 黎明技術學院                               6               6
# 龍華科技大學                               5               5

# %%
print('There are {} uniques categories.'.format(len(uni_venues['Venue Category'].unique())))
# Out:
# There are 262 uniques categories.

# %% [markdown]
# #### 2.2.2 Retrieving Gym Related Category IDs

# %%
page = requests.get("https://developer.foursquare.com/docs/build-with-foursquare/categories/")

# %%
soup = BeautifulSoup(page.content, 'html.parser')
all_categories_raw = soup.find_all('ul', class_='VenueCategories__Wrapper-sc-1ysxg0y-0 dikXMT')[0]

all_categories_name = all_categories_raw.find_all('h3')
all_categories_id = all_categories_raw.find_all('p')
all_categories_name = [cat.get_text() for cat in all_categories_name]
all_categories_id = [cat.get_text() for cat in all_categories_id]
all_categories_id = list(filter(lambda x: len(x) == 24, all_categories_id))

cat_df = pd.DataFrame({'Name': all_categories_name, 'ID': all_categories_id})
cat_df.head()
# Out:
#                    Name                        ID
# 0  Arts & Entertainment  4d4b7104d754a06370d81259
# 1          Amphitheater  56aa371be4b08b9a8d5734db
# 2              Aquarium  4fceea171983d5d06c3e9823
# 3                Arcade  4bf58dd8d48988d1e1931735
# 4           Art Gallery  4bf58dd8d48988d1e2931735

# %%
cat_df.to_csv('assets/data/categories_id_2021-02-20.csv', index=False)

# %% [markdown]
# After exporting the list of names and IDs of categories for future use, I'd like to find out the ones that represent sports facility. If you are more into gyms, you can probably choose the schools that offer more gyms in vicinity.

# %%
sports_categories = ['Gym', 'Gym / Fitness Center', 'Athletics & Sports', 'Climbing Gym', 'College Gym', 'Gymnastics Gym' , 'Beach', 'Bike Trail', 'Dive Spot', 'Fishing Spot', 'Park', 'Recreation Center', 'Rock Climbing Spot', 'Ski Area']

# %%
categories_id = ','.join(map(str, cat_df[cat_df['Name'].str.contains('Gym')].ID.to_list())) 
sports_categories_id = ','.join(map(str, cat_df[cat_df['Name'].isin(sports_categories)].ID.to_list()))

# %%
def getNearbySportsVenues(namess, latitudes, longitudes, radius=1000):
    venues_list=[]
    full_list = [] # for future reference, can be handful when examining different radius (don't haeve to rerun the quries again)
    (names, eng_names) = namess
    for name, eng_name, lat, lng in tzip(names, eng_names, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            sports_categories_id, # categories_id
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        full_list.append(results)
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, eng_name,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['University (zh)', 'University (eng)', 
                  'University Latitude', 
                  'University Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return nearby_venues, full_list

# %% [markdown]
# I am retrieving two dataset, one having a radius of 1000m and the other with 2000m. Biking 2k to a gym is not terribly far, and it can also serve as a sort of warm-ups. I personally go to gym that is 1.7km far away from my current location and it takes between 10-15 minutes to get there.

# %%
# Gym only
uni_sports_venues = pd.DataFrame()
uni_sports_venues, full_sports_list_raw = getNearbySportsVenues((np.asarray(udf['Name']), np.asarray(udf['Eng. Name'])), np.asarray(udf.Latitude), np.asarray(udf.Longitude), radius=1000)
uni_sports_venues_2000, full_sports_list_raw_2000 = getNearbySportsVenues((np.asarray(udf['Name']), np.asarray(udf['Eng. Name'])), np.asarray(udf.Latitude), np.asarray(udf.Longitude), radius=2000)
print(uni_sports_venues.shape)
uni_sports_venues.head()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=160.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=160.0), HTML(value='')))
# (136, 8)
#   University (zh)               University (eng)  University Latitude  \
# 0          國立清華大學  National Tsing Hua University             24.79635
# 1          國立清華大學  National Tsing Hua University             24.79635
# 2          國立清華大學  National Tsing Hua University             24.79635
# 3          國立臺灣大學     NATIONAL TAIWAN UNIVERSITY             25.01697
# 4          國立臺灣大學     NATIONAL TAIWAN UNIVERSITY             25.01697
#
#    University Longitude                  Venue  Venue Latitude  \
# 0             120.99686  清華大學新體育館 NTHU Stadium       24.793868
# 1             120.99686               NCTU Gym       24.789599
# 2             120.99686     NCTU Swimming Pool       24.789435
# 3             121.53369              World Gym       25.014470
# 4             121.53369               台灣大學舊體育館       25.019733
#
#    Venue Longitude        Venue Category
# 0       120.992318       College Stadium
# 1       120.995678           College Gym
# 2       120.995600              Gym Pool
# 3       121.534600  Gym / Fitness Center
# 4       121.535821           College Gym

# %%
print('Within 1000m:')
print(uni_sports_venues.shape)
print('There are {} uniques categories.'.format(len(uni_sports_venues['Venue Category'].unique())))

print('Within 2000m:')
print(uni_sports_venues_2000.shape)
print('There are {} uniques categories.'.format(len(uni_sports_venues_2000['Venue Category'].unique())))
# Out:
# Within 1000m:
# (136, 8)
# There are 16 uniques categories.
# Within 2000m:
# (487, 8)
# There are 21 uniques categories.

# %%
uni_sports_venues.to_csv('assets/data/uni_gym_venues_2021-02-20.csv', index=False)
uni_sports_venues_2000.to_csv('assets/data/uni_gym_venues_2000_2021-02-20.csv', index=False)

# %%
# All Exercise Facilities
uni_sports_venues = pd.DataFrame()
uni_sports_venues, full_sports_list_raw = getNearbySportsVenues((np.asarray(udf['Name']), np.asarray(udf['Eng. Name'])), np.asarray(udf.Latitude), np.asarray(udf.Longitude), radius=1000)
uni_sports_venues_2000, full_sports_list_raw_2000 = getNearbySportsVenues((np.asarray(udf['Name']), np.asarray(udf['Eng. Name'])), np.asarray(udf.Latitude), np.asarray(udf.Longitude), radius=2000)
print(uni_sports_venues.shape)
uni_sports_venues.head()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=160.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=160.0), HTML(value='')))
# (395, 8)
#   University (zh)                University (eng)  University Latitude  \
# 0          國立政治大學  National Chengchi Universerity             24.98741
# 1          國立政治大學  National Chengchi Universerity             24.98741
# 2          國立政治大學  National Chengchi Universerity             24.98741
# 3          國立政治大學  National Chengchi Universerity             24.98741
# 4          國立清華大學   National Tsing Hua University             24.79635
#
#    University Longitude                    Venue  Venue Latitude  \
# 0             121.57651      Roman Square (羅馬廣場)       24.986799
# 1             121.57651                 道南右岸河濱公園       24.995167
# 2             121.57651                   政大堤外球場       24.984681
# 3             121.57651  政大網球場(山上) Tennis Courts       24.981970
# 4             120.99686    清華大學新體育館 NTHU Stadium       24.793868
#
#    Venue Longitude        Venue Category
# 0       121.574540                 Plaza
# 1       121.572406                  Park
# 2       121.572953        Baseball Field
# 3       121.578353  College Tennis Court
# 4       120.992318       College Stadium

# %%
print('Within 1000m:')
print(uni_sports_venues.shape)
print('There are {} uniques categories.'.format(len(uni_sports_venues['Venue Category'].unique())))

print('Within 2000m:')
print(uni_sports_venues_2000.shape)
print('There are {} uniques categories.'.format(len(uni_sports_venues_2000['Venue Category'].unique())))
# Out:
# Within 1000m:
# (395, 8)
# There are 45 uniques categories.
# Within 2000m:
# (1352, 8)
# There are 64 uniques categories.

# %%
uni_sports_venues.to_csv('assets/data/uni_sports_venues_2021-02-20.csv', index=False)
uni_sports_venues_2000.to_csv('assets/data/uni_sports_venues_2000_2021-02-20.csv', index=False)
